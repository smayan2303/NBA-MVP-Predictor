# %%
import pandas as pd

# %%
stats = pd.read_csv("Player_Mvp_Stats.csv")

# %%
stats
# Out:
#        Unnamed: 0             Player   Age           Team  Pos     G    GS  \
# 0               0         Doc Rivers  29.0  Atlanta Hawks   PG  79.0  79.0
# 1               1  Dominique Wilkins  31.0  Atlanta Hawks   SF  81.0  81.0
# 2               2      Duane Ferrell  25.0  Atlanta Hawks   SF  78.0   2.0
# 3               3       Gary Leonard  23.0  Atlanta Hawks    C   4.0   0.0
# 4               4        John Battle  28.0  Atlanta Hawks   SG  79.0   2.0
# ...           ...                ...   ...            ...  ...   ...   ...
# 15854       15854      Luka DonÄiÄ   NaN            NaN  NaN   NaN   NaN
# 15855       15855      Nikola JokiÄ   NaN            NaN  NaN   NaN   NaN
# 15856       15856     League Average   NaN            NaN  NaN   NaN   NaN
# 15857       15857      Luka DonÄiÄ   NaN            NaN  NaN   NaN   NaN
# 15858       15858      Nikola JokiÄ   NaN            NaN  NaN   NaN   NaN
#
# ...

# %%
stats = stats[stats["Player"] != "League Average"]

# %%
stats = stats.fillna(0)

# %%
stats = stats.drop(columns=["Unnamed: 0"])

# %%
stats.columns
# Out:
# Index(['Player', 'Age', 'Team', 'Pos', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'Awards',
#        'Year', 'Pts Won', 'Pts Max', 'Share', 'W', 'L', 'W/L%', 'GB', 'PS/G',
#        'PA/G', 'SRS'],
#       dtype='object')

# %%
predictors = ["Age", "G", "GS", "MP", "FG", "FGA", 'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 
              'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'W', 'L', 'W/L%','GB', 'PS/G', 'PA/G', 'SRS']

# %%
train = stats[~(stats["Year"] == 2024)]
test = stats[stats["Year"] == 2024]

# %%
from sklearn.linear_model import Ridge
reg = Ridge(alpha=.1)

# %%
reg.fit(train[predictors], train["Share"])
# Out:
# Ridge(alpha=0.1)

# %%
predictions = reg.predict(test[predictors])

# %%
predictions = pd.DataFrame(predictions, columns=["predictions"], index = test.index)

# %%
predictions
# Out:
#        predictions
# 524      -0.026819
# 525       0.001020
# 526      -0.005668
# 527       0.005129
# 528      -0.003884
# ...            ...
# 15805    -0.030867
# 15806     0.005316
# 15807     0.001954
# 15857     0.181789
# 15858     0.181789
#
# [574 rows x 1 columns]

# %%
combination = pd.concat([test[["Player", "Share"]], predictions], axis=1)

# %%
combination.sort_values("Share", ascending = False).head(9)
# Out:
#                         Player  Share  predictions
# 15858            Nikola JokiÄ  0.935     0.181789
# 10697  Shai Gilgeous-Alexander  0.646     0.162644
# 15857            Luka DonÄiÄ  0.572     0.181789
# 8656     Giannis Antetokounmpo  0.194     0.199888
# 10413            Jalen Brunson  0.143     0.096952
# 1067              Jayson Tatum  0.087     0.108651
# 9169           Anthony Edwards  0.018     0.086008
# 13338         Domantas Sabonis  0.003     0.083906
# 12295             Kevin Durant  0.001     0.095461

# %%
x = combination[combination["Share"]> 0].shape[0]

# %%
combination.sort_values("predictions", ascending = False).head(20)
# Out:
#                         Player  Share  predictions
# 8656     Giannis Antetokounmpo  0.194     0.199888
# 11770              Joel Embiid  0.000     0.196457
# 15857            Luka DonÄiÄ  0.572     0.181789
# 15858            Nikola JokiÄ  0.935     0.181789
# 3434               Luka Dončić  0.000     0.174059
# 10697  Shai Gilgeous-Alexander  0.646     0.162644
# 3970              Nikola Jokić  0.000     0.157583
# 7172             Anthony Davis  0.000     0.125161
# 7184              LeBron James  0.000     0.117823
# 1067              Jayson Tatum  0.087     0.108651
# 13886        Victor Wembanyama  0.000     0.098136
# 10413            Jalen Brunson  0.143     0.096952
# 12295             Kevin Durant  0.001     0.095461
# 9869           Zion Williamson  0.000     0.095031
# 7567                 Ja Morant  0.000     0.091139
# 12287             Devin Booker  0.000     0.087035
# 2873          Donovan Mitchell  0.000     0.087010
# ...

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(combination["Share"], combination["predictions"])
# The mean squared error is very low, i am cracked
# However, a lot of values in the table are 0 so this metric is not very meaningful as an error metric for this project
# Out:
# np.float64(0.0024736128183231337)

# %%
combination = combination.sort_values("Share", ascending=False)
combination["Rk"] = list(range(1,combination.shape[0]+1))
combination = combination.sort_values("predictions", ascending=False)
combination["Predicted_Rk"] = list(range(1,combination.shape[0]+1))

# %%
combination.head(10)
# Out:
#                         Player  Share  predictions   Rk  Predicted_Rk
# 8656     Giannis Antetokounmpo  0.194     0.199888    4             1
# 11770              Joel Embiid  0.000     0.196457  427             2
# 15857            Luka DonÄiÄ  0.572     0.181789    3             3
# 15858            Nikola JokiÄ  0.935     0.181789    1             4
# 3434               Luka Dončić  0.000     0.174059  125             5
# 10697  Shai Gilgeous-Alexander  0.646     0.162644    2             6
# 3970              Nikola Jokić  0.000     0.157583  144             7
# 7172             Anthony Davis  0.000     0.125161  243             8
# 7184              LeBron James  0.000     0.117823  255             9
# 1067              Jayson Tatum  0.087     0.108651    6            10

# %%
combination.loc[combination["Share"] == 0, "Rk"] = x + 1
## Set the rank of everyone that got 0 mvp votes to 1 + the number of people that got mvp votes

# %%
combination.head(10)
# Out:
#                         Player  Share  predictions  Rk  Predicted_Rk
# 8656     Giannis Antetokounmpo  0.194     0.199888   4             1
# 11770              Joel Embiid  0.000     0.196457  10             2
# 15857            Luka DonÄiÄ  0.572     0.181789   3             3
# 15858            Nikola JokiÄ  0.935     0.181789   1             4
# 3434               Luka Dončić  0.000     0.174059  10             5
# 10697  Shai Gilgeous-Alexander  0.646     0.162644   2             6
# 3970              Nikola Jokić  0.000     0.157583  10             7
# 7172             Anthony Davis  0.000     0.125161  10             8
# 7184              LeBron James  0.000     0.117823  10             9
# 1067              Jayson Tatum  0.087     0.108651   6            10

# %%
#average precision metric algorithm
def find_ap(combination):
    actual = combination.sort_values("Share", ascending=False).head(x)
    predicted = combination.sort_values("predictions", ascending=False)
    ps = []
    found = 0
    seen = 1
    for index, row in predicted.iterrows():
        if row["Player"] in actual["Player"].values:
            found += 1
            ps.append(found / seen)
        seen += 1
    return sum(ps) / len(ps)

# %%
find_ap(combination)
# Out:
# 0.6155470585295146

# %%
years = list(range(1991,2025))

# %%
aps = []
all_predictions = []
for year in years[5:]:
    train = stats[stats["Year"] < year]
    test = stats[stats["Year"] == year]
    reg.fit(train[predictors],train["Share"])
    predictions = reg.predict(test[predictors])
    predictions = pd.DataFrame(predictions, columns=["predictions"], index=test.index)
    combination = pd.concat([test[["Player", "Share"]], predictions], axis=1)
    all_predictions.append(combination)
    aps.append(find_ap(combination))

# %%
sum(aps) / len(aps)
# Out:
# 0.7226021708516617

# %%
def add_ranks(predictions):
    x = predictions[predictions["Share"]> 0].shape[0]
    predictions = predictions.sort_values("predictions", ascending=False)
    predictions["Predicted_Rk"] = list(range(1,predictions.shape[0]+1))
    predictions = predictions.sort_values("Share", ascending=False)
    predictions["Rk"] = list(range(1,predictions.shape[0]+1))
    predictions["Diff"] = (predictions["Rk"] - predictions["Predicted_Rk"])
    predictions.loc[predictions["Share"] == 0, "Rk"] = x + 1
    return predictions

# %%
add_ranks(all_predictions[2016-1996]).head(10)
# Out:
#                   Player  Share  predictions  Predicted_Rk  Rk  Diff
# 4910       Stephen Curry  1.000     0.167852             1   1     0
# 13740      Kawhi Leonard  0.484     0.105719            10   2    -8
# 2726        LeBron James  0.482     0.154039             2   3     1
# 10549  Russell Westbrook  0.371     0.129048             6   4    -2
# 10543       Kevin Durant  0.112     0.153875             3   5     2
# 6510          Chris Paul  0.082     0.114777             9   6    -3
# 4900      Draymond Green  0.038     0.084091            15   7    -8
# 12679     Damian Lillard  0.020     0.074586            21   8   -13
# 5430        James Harden  0.007     0.133548             5   9     4
# 14480         Kyle Lowry  0.005     0.080520            17  10    -7

# %%
def backtest(stats, model, year, predictors):
    aps = []
    all_predictions = []
    for year in years[5:]:
        train = stats[stats["Year"] < year]
        test = stats[stats["Year"] == year]
        model.fit(train[predictors],train["Share"])
        predictions = reg.predict(test[predictors])
        predictions = pd.DataFrame(predictions, columns=["predictions"], index=test.index)
        combination = pd.concat([test[["Player", "Share"]], predictions], axis=1)
        combination = add_ranks(combination)
        all_predictions.append(combination)
        aps.append(find_ap(combination))
    return sum(aps) / len(aps), aps , pd.concat(all_predictions)

# %%
average_aps, ap, all_predictions = backtest(stats, reg, years[5:], predictors)

# %%
average_aps
# Out:
# 0.7174508652270813

# %%
all_predictions[all_predictions["Rk"] < 5].sort_values("Diff").head(10)
#Look at who has the greatest difference between rank and predicted rank
#Notice that many of these are smaller players and guards
# Out:
#               Player  Share  predictions  Predicted_Rk  Rk  Diff
# 9362      Jason Kidd  0.712     0.027948            53   2   -51
# 11994     Steve Nash  0.839     0.032379            47   1   -46
# 12012     Steve Nash  0.739     0.050234            36   1   -35
# 2148     Joakim Noah  0.258     0.047124            38   4   -34
# 15843  Nikola JokiÄ  0.210     0.070661            34   4   -30
# 15849  Nikola JokiÄ  0.961     0.085203            27   1   -26
# 12027     Steve Nash  0.785     0.069745            23   2   -21
# 15845  Luka DonÄiÄ  0.198     0.082791            22   4   -18
# 7684    Tim Hardaway  0.207     0.059966            20   4   -16
# 12253   Devin Booker  0.216     0.090149            18   4   -14

# %%
pd.concat([pd.Series(reg.coef_), pd.Series(predictors)], axis=1).sort_values(0, ascending=False)
# Out:
#            0     1
# 13  0.121508  eFG%
# 18  0.027593   DRB
# 10  0.015486    2P
# 17  0.015102   ORB
# 12  0.014064   2P%
# 21  0.012653   STL
# 15  0.011816   FTA
# 22  0.011113   BLK
# 25  0.006987   PTS
# 5   0.006298   FGA
# 20  0.005970   AST
# 7   0.001597    3P
# 26  0.000954     W
# 29  0.000300    GB
# 0   0.000230   Age
# 1   0.000093     G
# 2   0.000011    GS
# 32 -0.000018   SRS
# 31 -0.000039  PA/G
# 30 -0.000849  PS/G
# 4  -0.001036    FG
# 27 -0.001209     L
# 24 -0.002537    PF
# 3  -0.003691    MP
# 16 -0.005707   FT%
# 14 -0.007580    FT
# 23 -0.008640   TOV
# 9  -0.009724   3P%
# 8  -0.011388   3PA
# 11 -0.015822   2PA
# 19 -0.021305   TRB
# 28 -0.118456  W/L%
# 6  -0.190735   FG%

# %%
stat_ratios = stats[["PTS", "AST", "STL", "BLK", "3P", "Year"]].groupby("Year").apply(lambda x: x/x.mean())
stats["PTS_R"] = stats['PTS'] / stats['PTS'].mean()
stats["AST_R"] = stats['AST'] / stats['AST'].mean()
stats["STL_R"] = stats['STL'] / stats['STL'].mean()
stats["BLK_R"] = stats['BLK'] / stats['BLK'].mean()
stats["3P_R"] = stats['3P'] / stats['3P'].mean()
predictors = predictors +  ["PTS_R", "AST_R", "STL_R", "BLK_R", "3P_R"]
mean_ap, aps, all_predictions = backtest(stats, reg, years[5:], predictors)
mean_ap
# Out:
# C:\Users\smaya\AppData\Local\Temp\ipykernel_41708\4262821738.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   stat_ratios = stats[["PTS", "AST", "STL", "BLK", "3P", "Year"]].groupby("Year").apply(lambda x: x/x.mean())
